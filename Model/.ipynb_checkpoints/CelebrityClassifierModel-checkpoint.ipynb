# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # (1) Preprocessing: Detect face and eyes

# %% [markdown]
# When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.
# We will use haar cascade from OpenCV for this.

# %%
img = cv2.imread('./Test_Images/image1.jpeg')
img.shape
# Out:
# (189, 267, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (189, 267)

# %%
gray
# Out:
# array([[252, 252, 253, ...,  14,  14,  14],
#        [250, 252, 253, ...,  14,  14,  14],
#        [247, 250, 253, ...,  14,  14,  14],
#        ...,
#        [ 29,  30,  35, ...,  20,  20,  20],
#        [ 28,  29,  33, ...,  20,  20,  20],
#        [ 27,  24,  28, ...,  20,  20,  20]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[118,  51,  98,  98]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (118, 51, 98, 98)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),1)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),1)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# # (2) Preprocessing: Crop the facial region of the image

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (98, 98, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    roi=[]
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            roi.append(roi_color)
    return roi

# %%
original_image = cv2.imread('./Test_Images/image2.jpeg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./Test_Images/image2.jpeg')
for i in cropped_image:
    plt.imshow(i)

# %%
path_to_data = "./DataSet/"
path_to_cr_data = "./DataSet/Cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./DataSet/Cropped',
#  './DataSet/Mohit_Raina',
#  './DataSet/Nakuul_Mehta',
#  './DataSet/Rajeev_Khandelwal',
#  './DataSet/Vicky_Kaushal',
#  './DataSet/Virat_Kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    for entry in os.scandir(img_dir):
        roi = get_cropped_image_if_2_eyes(entry.path)
        for roi_color in roi:
            if roi_color is not None:
                cropped_folder = path_to_cr_data + celebrity_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ",cropped_folder)

                cropped_file_name = celebrity_name + str(count) + ".png"
                cropped_file_path = cropped_folder + "/" + cropped_file_name 
                cv2.imwrite(cropped_file_path, roi_color)
                count += 1
# Out:
# Cropped
# Mohit_Raina
# Generating cropped images in folder:  ./DataSet/Cropped/Mohit_Raina
# Nakuul_Mehta
# Generating cropped images in folder:  ./DataSet/Cropped/Nakuul_Mehta
# Rajeev_Khandelwal
# Generating cropped images in folder:  ./DataSet/Cropped/Rajeev_Khandelwal
# Vicky_Kaushal
# Generating cropped images in folder:  ./DataSet/Cropped/Vicky_Kaushal
# Virat_Kohli
# Generating cropped images in folder:  ./DataSet/Cropped/Virat_Kohli

# %% [markdown]
# Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region.

# %% [markdown]
# Now we have 'Cropped' folder under datasets folder that contains cropped images. Manually examine cropped folder and delete any unwanted images

# %%
img_dirs = []
for entry in os.scandir(path_to_cr_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
        
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        celebrity_file_names_dict[celebrity_name].append(entry.path)

# %%
celebrity_file_names_dict
# Out:
# {'Mohit_Raina': ['./DataSet/Cropped/Mohit_Raina\\Mohit_Raina10.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina11.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina12.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina13.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina14.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina15.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina16.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina17.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina18.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina19.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina2.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina20.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina21.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina22.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina24.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina25.png',
#   './DataSet/Cropped/Mohit_Raina\\Mohit_Raina27.png',
# ...

# %% [markdown]
# # (3) Preprocessing: Use wavelet transform as a feature for traning our model

# %% [markdown]
# In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc.

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# Above is a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier.

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Mohit_Raina': 0,
#  'Nakuul_Mehta': 1,
#  'Rajeev_Khandelwal': 2,
#  'Vicky_Kaushal': 3,
#  'Virat_Kohli': 4}

# %% [markdown]
# Images in 'Cropped' folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Preparing X and Y now.

# %%
X, Y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        Y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[216],
#        [231],
#        [233],
#        ...,
#        [ 38],
#        [ 52],
#        [  6]], dtype=uint8)

# %%
Y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (308, 4096)

# %% [markdown]
# Data cleaning process is done. Now we will train our model

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, Y_train)
pipe.score(X_test, Y_test)
# Out:
# 0.7012987012987013

# %%
print(classification_report(Y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        16
#            1       0.90      0.64      0.75        14
#            2       0.70      0.86      0.78        22
#            3       0.82      0.74      0.78        19
#            4       0.44      0.67      0.53         6
#
#     accuracy                           0.70        77
#    macro avg       0.69      0.68      0.67        77
# weighted avg       0.72      0.70      0.70        77

# %% [markdown]
# We will use GridSearch to try out different models with different paramets. Goal is to come up with best model with best fine tuned parameters.

# %%
# !pip install lightgbm
# Out:
# ...
#      ---------------------------------------- 1.3/1.3 MB 132.1 kB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
import lightgbm as lgb
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,50,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10,15]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10,15,25]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)  ## Cross-Validation=5
    clf.fit(X_train, Y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.748751
# 1        random_forest    0.536355
# 2  logistic_regression    0.744588
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 15}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=15))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,Y_test)
# Out:
# 0.7272727272727273

# %%
best_estimators['random_forest'].score(X_test,Y_test)
# Out:
# 0.44155844155844154

# %%
best_estimators['logistic_regression'].score(X_test,Y_test)
# Out:
# 0.7012987012987013

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  2,  4,  1,  1],
#        [ 0, 11,  1,  1,  1],
#        [ 1,  1, 19,  1,  0],
#        [ 3,  0,  2, 14,  0],
#        [ 0,  0,  1,  1,  4]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Mohit_Raina': 0,
#  'Nakuul_Mehta': 1,
#  'Rajeev_Khandelwal': 2,
#  'Vicky_Kaushal': 3,
#  'Virat_Kohli': 4}

# %% [markdown]
# Saving our trained-model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'Saved_Model.pkl')
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\sneh omer\anaconda3\lib\site-packages)
# ['Saved_Model.pkl']

# %% [markdown]
# Save Class Dictionary : We will need it for further recognition.

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       1.3.0
# alabaster                     0.7.12
# anaconda-client               1.11.1
# anaconda-navigator            2.4.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# ...
